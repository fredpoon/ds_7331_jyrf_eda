# %%
import pandas as pd
schoolData = pd.read_csv('C:/Users/taniat470s/Desktop/SMU_course/DS7331/PublicSchools2014to2017_4ML_upd.csv') # read in the csv file
schoolData_SPG = pd.read_csv('C:/Users/taniat470s/Desktop/SMU_course/DS7331/PublicSchools2014to2017_SPG.csv') # read in the csv file

# %%
schoolData.shape
# Out:
# (9731, 148)

# %%
schoolData.describe()
# Out:
#             szip_ad  student_num  lea_avg_student_num  st_avg_student_num  \
# count   9731.000000  9731.000000          9731.000000         9731.000000
# mean   27981.523173   588.443634           588.456171          587.764053
# std      517.884899   381.356319           270.983795          150.891747
# min    27006.000000     1.000000             0.000000            0.000000
# 25%    27529.000000   346.000000           438.000000          490.000000
# 50%    28052.000000   520.000000           533.000000          496.000000
# 75%    28394.500000   731.000000           698.500000          665.000000
# max    28906.000000  2974.000000          1852.000000          860.000000
#
#        Math I_Size  lea_total_expense_num  lea_salary_expense_pct  \
# count  9731.000000            9731.000000             9731.000000
# mean      8.818107            8992.041761                0.673819
# std      11.182555            1023.850284                0.095480
# min       0.000000            7282.190000                0.547000
# 25%       0.000000            8362.900000                0.613000
# 50%       0.000000            8779.340000                0.628000
# 75%      20.000000            9326.890000                0.763000
# max      43.000000           17801.850000                0.878000
#
#        lea_services_expense_pct  lea_supplies_expense_pct  \
# count               9731.000000               9731.000000
# mean                   0.080056                  0.079985
# std                    0.014983                  0.016110
# min                    0.047000                  0.028000
# 25%                    0.069000                  0.069000
# 50%                    0.080000                  0.080000
# 75%                    0.087000                  0.091000
# max                    0.153000                  0.143000
#
#        lea_instruct_equip_exp_pct  ...  Grad_project_status_Y  \
# count                 9731.000000  ...            9731.000000
# mean                     0.008898  ...               0.089713
# std                      0.008045  ...               0.285785
# min                      0.000000  ...               0.000000
# 25%                      0.005000  ...               0.000000
# 50%                      0.007000  ...               0.000000
# 75%                      0.011000  ...               0.000000
# max                      0.065000  ...               1.000000
#
#        EVAAS Growth Status_Exceeded  EVAAS Growth Status_Met  \
# count                   9731.000000              9731.000000
# mean                       0.275203                 0.429144
# std                        0.446639                 0.494979
# min                        0.000000                 0.000000
# 25%                        0.000000                 0.000000
# 50%                        0.000000                 0.000000
# 75%                        1.000000                 1.000000
# max                        1.000000                 1.000000
#
#        EVAAS Growth Status_NotMet  Category_Cd_A  Category_Cd_E  \
# count                 9731.000000    9731.000000    9731.000000
# mean                     0.237899       0.015106       0.530264
# std                      0.425819       0.121982       0.499109
# min                      0.000000       0.000000       0.000000
# 25%                      0.000000       0.000000       0.000000
# 50%                      0.000000       0.000000       1.000000
# 75%                      0.000000       0.000000       1.000000
# max                      1.000000       1.000000       1.000000
#
#        Category_Cd_H  Category_Cd_I  Category_Cd_M  Category_Cd_T
# count    9731.000000    9731.000000    9731.000000    9731.000000
# mean        0.201726       0.034323       0.194122       0.024150
# std         0.401310       0.182068       0.395543       0.153521
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 148 columns]

# %%
schoolData.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9731 entries, 0 to 9730
# Data columns (total 148 columns):
#  #   Column                                                                           Dtype
# ---  ------                                                                           -----
#  0   szip_ad                                                                          int64
#  1   student_num                                                                      int64
#  2   lea_avg_student_num                                                              int64
#  3   st_avg_student_num                                                               int64
#  4   Math I_Size                                                                      int64
#  5   lea_total_expense_num                                                            float64
#  6   lea_salary_expense_pct                                                           float64
#  7   lea_services_expense_pct                                                         float64
#  8   lea_supplies_expense_pct                                                         float64
#  9   lea_instruct_equip_exp_pct                                                       float64
#  10  lea_federal_perpupil_num                                                         float64
#  11  lea_local_perpupil_num                                                           float64
#  12  lea_state_perpupil_num                                                           float64
#  13  pct_GCE_ALL                                                                      float64
#  14  MathGr3-8_pTarget_PctMet                                                         float64
#  15  SciGr5&8_pTarget_PctMet                                                          float64
#  16  TotalTargets_pTarget_PctMet                                                      float64
#  17  lea_sat_avg_score_num                                                            int64
#  18  lea_sat_participation_pct                                                        float64
#  19  lea_ap_participation_pct                                                         float64
#  20  lea_ap_pct_3_or_above                                                            float64
#  21  lea_ib_pct_4_or_above                                                            float64
#  22  avg_daily_attend_pct                                                             float64
#  23  crime_per_c_num                                                                  float64
#  24  short_susp_per_c_num                                                             float64
#  25  long_susp_per_c_num                                                              float64
#  26  expelled_per_c_num                                                               float64
#  27  stud_internet_comp_num                                                           float64
#  28  lea_avg_daily_attend_pct                                                         float64
#  29  lea_crime_per_c_num                                                              float64
#  30  lea_short_susp_per_c_num                                                         float64
#  31  lea_long_susp_per_c_num                                                          float64
#  32  lea_expelled_per_c_num                                                           float64
#  33  lea_stud_internet_comp_num                                                       float64
#  34  st_crime_per_c_num                                                               float64
#  35  flicensed_teach_pct                                                              float64
#  36  tchyrs_0thru3_pct                                                                float64
#  37  tchyrs_4thru10_pct                                                               float64
#  38  tchyrs_11plus_pct                                                                float64
#  39  nbpts_num                                                                        int64
#  40  advance_dgr_pct                                                                  float64
#  41  _1yr_tchr_trnovr_pct                                                             float64
#  42  lateral_teach_pct                                                                float64
#  43  lea_flicensed_teach_pct                                                          float64
#  44  lea_tchyrs_0thru3_pct                                                            float64
#  45  lea_tchyrs_4thru10_pct                                                           float64
#  46  lea_tchyrs_11plus_pct                                                            float64
#  47  lea_nbpts_num                                                                    int64
#  48  lea_advance_dgr_pct                                                              float64
#  49  lea_1yr_tchr_trnovr_pct                                                          float64
#  50  lea_emer_prov_teach_pct                                                          float64
#  51  st_flicensed_teach_pct                                                           float64
#  52  st_tchyrs_0thru3_pct                                                             float64
#  53  st_1yr_tchr_trnovr_pct                                                           float64
#  54  st_emer_prov_teach_pct                                                           float64
#  55  0-3 Years_LEA_Exp_Pct_Prin                                                       float64
#  56  10+ Years_LEA_Exp_Pct_Prin                                                       float64
#  57  4-10 Years_LEA_Exp_Pct_Prin                                                      float64
#  58  Accomplished_TCHR_Standard 1_Pct                                                 float64
#  59  Accomplished_TCHR_Standard 2_Pct                                                 float64
#  60  Accomplished_TCHR_Standard 3_Pct                                                 float64
#  61  Accomplished_TCHR_Standard 4_Pct                                                 float64
#  62  Accomplished_TCHR_Standard 5_Pct                                                 float64
#  63  Developing_TCHR_Standard 1_Pct                                                   float64
#  64  Developing_TCHR_Standard 2_Pct                                                   float64
#  65  Developing_TCHR_Standard 3_Pct                                                   float64
#  66  Developing_TCHR_Standard 4_Pct                                                   float64
#  67  Developing_TCHR_Standard 5_Pct                                                   float64
#  68  Distinguished_TCHR_Standard 1_Pct                                                float64
#  69  Distinguished_TCHR_Standard 2_Pct                                                float64
#  70  Distinguished_TCHR_Standard 3_Pct                                                float64
#  71  Distinguished_TCHR_Standard 4_Pct                                                float64
#  72  Distinguished_TCHR_Standard 5_Pct                                                float64
#  73  Not Demostrated_TCHR_Standard 1_Pct                                              float64
#  74  Not Demostrated_TCHR_Standard 2_Pct                                              float64
#  75  Not Demostrated_TCHR_Standard 4_Pct                                              float64
#  76  Proficient_TCHR_Standard 1_Pct                                                   float64
#  77  Proficient_TCHR_Standard 2_Pct                                                   float64
#  78  Proficient_TCHR_Standard 3_Pct                                                   float64
#  79  Proficient_TCHR_Standard 4_Pct                                                   float64
#  80  Proficient_TCHR_Standard 5_Pct                                                   float64
#  81  AsianFemalePct                                                                   float64
#  82  AsianMalePct                                                                     float64
#  83  BlackFemalePct                                                                   float64
#  84  BlackMalePct                                                                     float64
#  85  HispanicFemalePct                                                                float64
#  86  HispanicMalePct                                                                  float64
#  87  IndianFemalePct                                                                  float64
#  88  MinorityFemalePct                                                                float64
#  89  MinorityMalePct                                                                  float64
#  90  PacificIslandFemalePct                                                           float64
#  91  PacificIslandMalePct                                                             float64
#  92  PacificIslandPct                                                                 float64
#  93  TwoOrMoreFemalePct                                                               float64
#  94  TwoOrMoreMalePct                                                                 float64
#  95  TwoOrMorePct                                                                     float64
#  96  unit_code                                                                        int64
#  97  Year                                                                             int64
#  98  category_cd_A                                                                    int64
#  99  category_cd_E                                                                    int64
#  100 category_cd_H                                                                    int64
#  101 category_cd_I                                                                    int64
#  102 category_cd_M                                                                    int64
#  103 category_cd_T                                                                    int64
#  104 calendar_type_txt_Alternative Education, Traditional Calendar                    int64
#  105 calendar_type_txt_Hospital School                                                int64
#  106 calendar_type_txt_Magnet School, Traditional Calendar                            int64
#  107 calendar_type_txt_Magnet School, Year-Round Calendar                             int64
#  108 calendar_type_txt_Regular School, Traditional Calendar                           int64
#  109 calendar_type_txt_Regular School, Traditional Calendar plus Year-Round Calendar  int64
#  110 calendar_type_txt_Regular School, Year-Round Calendar                            int64
#  111 calendar_type_txt_Special Education, Traditional Calendar                        int64
#  112 calendar_type_txt_Vocational Education, Traditional Calendar                     int64
#  113 sna_pgm_type_cd_A                                                                int64
#  114 sna_pgm_type_cd_H                                                                int64
#  115 sna_pgm_type_cd_M                                                                int64
#  116 sna_pgm_type_cd_N                                                                int64
#  117 sna_pgm_type_cd_R                                                                int64
#  118 sna_pgm_type_cd_S                                                                int64
#  119 sna_pgm_type_cd_V                                                                int64
#  120 sna_pgm_type_cd_X                                                                int64
#  121 sna_pgm_type_cd_Y                                                                int64
#  122 school_type_txt_Alternative Education                                            int64
#  123 school_type_txt_Hospital School                                                  int64
#  124 school_type_txt_Magnet School                                                    int64
#  125 school_type_txt_Regular School                                                   int64
#  126 school_type_txt_Special Education                                                int64
#  127 school_type_txt_Vocational Education                                             int64
#  128 calendar_only_txt_Traditional Calendar                                           int64
#  129 calendar_only_txt_Traditional Calendar plus Year-Round Calendar                  int64
#  130 calendar_only_txt_Year-Round Calendar                                            int64
#  131 title1_type_cd_Y                                                                 int64
#  132 esea_status_F                                                                    int64
#  133 esea_status_P                                                                    int64
#  134 esea_status_R                                                                    int64
#  135 esea_status_RF                                                                   int64
#  136 esea_status_RP                                                                   int64
#  137 Grad_project_status_N                                                            int64
#  138 Grad_project_status_Y                                                            int64
#  139 EVAAS Growth Status_Exceeded                                                     int64
#  140 EVAAS Growth Status_Met                                                          int64
#  141 EVAAS Growth Status_NotMet                                                       int64
#  142 Category_Cd_A                                                                    int64
#  143 Category_Cd_E                                                                    int64
#  144 Category_Cd_H                                                                    int64
#  145 Category_Cd_I                                                                    int64
#  146 Category_Cd_M                                                                    int64
#  147 Category_Cd_T                                                                    int64
# dtypes: float64(88), int64(60)
# memory usage: 11.0 MB

# %%
#Drop NAs
comb3 = pd.concat([schoolData, schoolData_SPG],axis=1)
comb3 = comb3.dropna()
comb3.shape
# Out:
# (9731, 149)

# %%
ya = comb3[['SPG Grade']].values
if 'SPG Grade' in comb3:
    del comb3['SPG Grade']     
Xa = comb3.values


Xa
ya
# Out:
# array([['A'],
#        ['C'],
#        ['C'],
#        ...,
#        ['B'],
#        ['B'],
#        ['B']], dtype=object)

# %%
from sklearn.ensemble import RandomForestClassifier
clfa=RandomForestClassifier(n_estimators=100)
clfa.fit(Xa,ya)
y_pred=clfa.predict(Xa)
# Out:
# C:\Users\taniat470s\Anaconda3\envs\ML7331\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(ya, y_pred))
# Out:
# Accuracy: 1.0

# %%
import eli5
from eli5.sklearn import PermutationImportance
perm = PermutationImportance(clfa, random_state=1).fit(Xa,ya)
eli5.show_weights(perm, feature_names = comb3.columns.tolist(), top=50)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0215
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 TotalTargets_pTarget_PctMet
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0163
#
#                     &plusmn; 0.0017
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EVAAS Growth Status_NotMet
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.67%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0083
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MinorityMalePct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0039
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MinorityFemalePct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.60%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0017
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 title1_type_cd_Y
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0014
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 short_susp_per_c_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0011
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 avg_daily_attend_pct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0009
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BlackMalePct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.49%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AsianFemalePct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EVAAS Growth Status_Exceeded
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BlackFemalePct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 nbpts_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lea_ap_participation_pct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HispanicMalePct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AsianMalePct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MathGr3-8_pTarget_PctMet
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Proficient_TCHR_Standard 2_Pct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.52%); border: none;">
#             <td

# %%
schoolData_pick = schoolData[['lea_federal_perpupil_num','avg_daily_attend_pct','MinorityFemalePct']]
#schoolData_pick = schoolData[['lea_federal_perpupil_num','avg_daily_attend_pct']]

#Drop NAs
temp = pd.concat([schoolData_pick, schoolData_SPG],axis=1)
temp = temp.dropna()
temp.shape

ys1 = temp[['SPG Grade']].values
if 'SPG Grade' in temp:
    del temp['SPG Grade']     
Xs1 = temp.values


Xs1
ys1
# Out:
# (9731, 4)
# array([[1.00640000e+03, 8.72000000e-01, 2.43243243e-01],
#        [1.00640000e+03, 9.57000000e-01, 1.57699443e-01],
#        [1.00640000e+03, 9.54000000e-01, 9.40959410e-02],
#        ...,
#        [1.23554000e+03, 9.44000000e-01, 6.21468930e-02],
#        [1.23554000e+03, 9.45000000e-01, 4.48807850e-02],
#        [1.23554000e+03, 9.39000000e-01, 1.02564103e-01]])
# array([['A'],
#        ['C'],
#        ['C'],
#        ...,
#        ['B'],
#        ['B'],
#        ['B']], dtype=object)

# %%
clfs1=RandomForestClassifier(n_estimators=100)
clfs1.fit(Xs1,ys1)
y_preds1=clfs1.predict(Xs1)

print("Accuracy:",metrics.accuracy_score(ys1, y_preds1))
# Out:
# C:\Users\taniat470s\Anaconda3\envs\ML7331\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Accuracy: 0.8117356900626863

# %%
perm = PermutationImportance(clfs1, random_state=1).fit(Xs1,ys1)
eli5.show_weights(perm, feature_names = temp.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4931
#
#                     &plusmn; 0.0082
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 avg_daily_attend_pct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4746
#
#                     &plusmn; 0.0115
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lea_federal_perpupil_num
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
y_preds1.dtype
# Out:
# dtype('O')

# %%
import matplotlib.pyplot as plt
sns.factorplot(y_preds1, aspect=2,
                       kind="count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-508bcb875e52> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 sns.factorplot(y_preds1, aspect=2,
#       3                        kind="count")
#       4 plt.show()
#
# NameError: name 'sns' is not defined

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from sklearn.model_selection import ShuffleSplit

num_cv_iterations = 3
num_instances = len(schoolData_SPG)
cv_object = ShuffleSplit(n_splits=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %%
from sklearn.preprocessing import StandardScaler
# we want to normalize the features based upon the mean and standard deviation of each column. 
# However, we do not want to accidentally use the testing data to find out the mean and std (this would be snooping)

from sklearn.pipeline import Pipeline
# you can apply the StandardScaler function inside of the cross-validation loop 
#  but this requires the use of PipeLines in scikit. 
#  A pipeline can apply feature pre-processing and data fitting in one compact notation
#  Here is an example!

# scale attributes by the training set
scl_obj = StandardScaler()

# okay, so run through the cross validation loop and set the training and testing variable for one single iteration
for train_indices, test_indices in cv_object.split(Xa,ya): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = Xa[train_indices]
    y_train = ya[train_indices]
    
    X_test = Xa[test_indices]
    y_test = ya[test_indices]

# %%
clfa2=RandomForestClassifier(n_estimators=100)
clfa2.fit(X_train,y_train)
y_pred2=clfa2.predict(X_test)
# Out:
# C:\Users\taniat470s\Anaconda3\envs\ML7331\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred2))
# Out:
# Accuracy: 0.7395993836671803

# %%
perm = PermutationImportance(clfa, random_state=1).fit(X_test,y_test)
eli5.show_weights(perm, feature_names = comb3.columns.tolist(), top=50)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0230
#
#                     &plusmn; 0.0031
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 TotalTargets_pTarget_PctMet
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 81.98%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0198
#
#                     &plusmn; 0.0034
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EVAAS Growth Status_NotMet
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0080
#
#                     &plusmn; 0.0017
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MinorityMalePct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.10%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0050
#
#                     &plusmn; 0.0008
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MinorityFemalePct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0016
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 title1_type_cd_Y
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0009
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 avg_daily_attend_pct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.60%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 short_susp_per_c_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0004
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BlackMalePct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AsianFemalePct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 student_num
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.26%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0002
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HispanicMalePct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SciGr5&amp;8_pTarget_PctMet
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 tchyrs_0thru3_pct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 tchyrs_11plus_pct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Accomplished_TCHR_Standard 2_Pct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Accomplished_TCHR_Standard 1_Pct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Developing_TCHR_Standard 1_Pct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">

# %%
for train_indices, test_indices in cv_object.split(Xs1,ys1): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    Xs_train = Xs1[train_indices]
    ys_train = ys1[train_indices]
    
    Xs_test = Xs1[test_indices]
    ys_test = ys1[test_indices]

# %%
ys_test
# Out:
# array([['B'],
#        ['F'],
#        ['B'],
#        ...,
#        ['C'],
#        ['B'],
#        ['B']], dtype=object)

# %%
clfs2=RandomForestClassifier(n_estimators=100)
clfs2.fit(Xs_train,ys_train)
y_preds2=clfs2.predict(Xs_test)

print("Accuracy:",metrics.accuracy_score(ys_test, y_preds2))
# Out:
# C:\Users\taniat470s\Anaconda3\envs\ML7331\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# Accuracy: 0.5095017976373909

# %%
perm = PermutationImportance(clfs2, random_state=1).fit(Xs_test,ys_test)
eli5.show_weights(perm, feature_names = temp.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1351
#
#                     &plusmn; 0.0121
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MinorityFemalePct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.49%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1027
#
#                     &plusmn; 0.0075
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 avg_daily_attend_pct
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0806
#
#                     &plusmn; 0.0153
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lea_federal_perpupil_num
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
# schoolData_pick2 = schoolData[['avg_daily_attend_pct',
#          'crime_per_c_num','EVAAS Growth Status_Exceeded','EVAAS Growth Status_Met','EVAAS Growth Status_NotMet','lea_federal_perpupil_num',
#          'MinorityFemalePct','MinorityMalePct','Proficient_TCHR_Standard 1_Pct','short_susp_per_c_num','student_num',
#          'tchyrs_0thru3_pct','Year']]

schoolData_pick2 = schoolData[[
'TotalTargets_pTarget_PctMet',
'EVAAS Growth Status_NotMet',
'MinorityMalePct',
'MinorityFemalePct',
'title1_type_cd_Y',
'avg_daily_attend_pct',
'short_susp_per_c_num',
'BlackMalePct',
'AsianFemalePct',
'student_num',
'HispanicMalePct',
'SciGr5&8_pTarget_PctMet',
'tchyrs_0thru3_pct',
'tchyrs_11plus_pct',
'Accomplished_TCHR_Standard 2_Pct',
'Accomplished_TCHR_Standard 1_Pct',
'Developing_TCHR_Standard 1_Pct',
'Developing_TCHR_Standard 2_Pct',
'Developing_TCHR_Standard 3_Pct',
'Accomplished_TCHR_Standard 4_Pct',
'4-10 Years_LEA_Exp_Pct_Prin',
'Developing_TCHR_Standard 4_Pct',
'Developing_TCHR_Standard 5_Pct',
'10+ Years_LEA_Exp_Pct_Prin',
'Accomplished_TCHR_Standard 3_Pct',
'Accomplished_TCHR_Standard 5_Pct',
'lea_state_perpupil_num',
'st_emer_prov_teach_pct',
'pct_GCE_ALL',
'MathGr3-8_pTarget_PctMet',
'lea_sat_avg_score_num',
'lea_federal_perpupil_num',
'lea_local_perpupil_num',
'nbpts_num',
'Distinguished_TCHR_Standard 2_Pct',
'_1yr_tchr_trnovr_pct',
'lateral_teach_pct',
'0-3 Years_LEA_Exp_Pct_Prin',
'lea_flicensed_teach_pct',
'lea_tchyrs_4thru10_pct',
'lea_tchyrs_11plus_pct',
'lea_nbpts_num',
'lea_advance_dgr_pct',
'lea_1yr_tchr_trnovr_pct',
'lea_emer_prov_teach_pct',
'st_flicensed_teach_pct',
'st_tchyrs_0thru3_pct',
'st_1yr_tchr_trnovr_pct',
'lea_tchyrs_0thru3_pct',
'Category_Cd_T',
]]
#Drop NAs
temp = pd.concat([schoolData_pick2, schoolData_SPG],axis=1)
temp = temp.dropna()
temp.shape

ys2 = temp[['SPG Grade']].values
if 'SPG Grade' in temp:
    del temp['SPG Grade']     
Xs2 = temp.values


Xs2
ys2
# Out:
# (9731, 51)
# array([[1.        , 0.        , 0.06756757, ..., 0.156     , 0.179     ,
#         0.        ],
#        [1.        , 0.        , 0.16326531, ..., 0.128     , 0.251     ,
#         0.        ],
#        [0.966     , 0.        , 0.10701107, ..., 0.128     , 0.251     ,
#         0.        ],
#        ...,
#        [1.        , 0.        , 0.06779661, ..., 0.129     , 0.133     ,
#         0.        ],
#        [0.96      , 0.        , 0.0631136 , ..., 0.13      , 0.103     ,
#         0.        ],
#        [1.        , 0.        , 0.04273504, ..., 0.129     , 0.133     ,
#         0.        ]])
# array([['A'],
#        ['C'],
#        ['C'],
#        ...,
#        ['B'],
#        ['B'],
#        ['B']], dtype=object)

# %%
for train_indices, test_indices in cv_object.split(Xs2,ys2): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    Xs2_train = Xs2[train_indices]
    ys2_train = ys2[train_indices]
    
    Xs2_test = Xs2[test_indices]
    ys2_test = ys2[test_indices]

# %%
clfs3=RandomForestClassifier(n_estimators=100)
clfs3.fit(Xs2_train,ys2_train)
y_preds3=clfs3.predict(Xs2_test)

print("Accuracy:",metrics.accuracy_score(ys2_test, y_preds3))
# Out:
# C:\Users\taniat470s\Anaconda3\envs\ML7331\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# Accuracy: 0.7442218798151001

# %% [markdown]
# ## SVM Work

# %%
Xs2_train_scaled = scl_obj.fit_transform(Xs2_train) # apply to training
Xs2_test_scaled = scl_obj.fit_transform(Xs2_test)

# %%
# lets investigate SVMs on the data and play with the parameters and kernels
from sklearn.svm import SVC
from sklearn import metrics as mt

# train the model just as before
svm_clf = SVC(C=0.5, kernel='rbf', degree=3, gamma='auto') # get object
svm_clf.fit(Xs2_train_scaled, ys2_train)  # train object

y_hat = svm_clf.predict(Xs2_test_scaled) # get test set precitions

acc = mt.accuracy_score(ys2_test,y_hat)
conf = mt.confusion_matrix(ys2_test,y_hat)
print('accuracy:', acc )
print(conf)
# Out:
# C:\Users\taniat470s\Anaconda3\envs\ML7331\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=0.5, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# accuracy: 0.687211093990755
# [[ 63   0   0   1   4   3   0   0]
#  [  1  31   0  47   3   0   0   0]
#  [  0  12   0  37   1   0   0   0]
#  [  0  11   0 312 141   5   0   0]
#  [  3   0   0  68 627  77   0   1]
#  [  2   0   0   0 109 264   6   0]
#  [  2   0   0   0   2  73  19   0]
#  [  0   0   0   0   0   0   0  22]]

# %%
f = plt.figure(figsize=(8,8))
plt.imshow(conf)

# %%
# look at the support vectors
print(svm_clf.support_vectors_.shape)
print(svm_clf.support_.shape)
print(svm_clf.n_support_ )
# Out:
# (6457, 50)
# (6457,)
# [ 222  280  155 1557 2423 1405  334   81]

# %%
# Now let's do some different analysis with the SVM and look at the instances that were chosen as support vectors

# now lets look at the support for the vectors and see if we they are indicative of anything
# grabe the rows that were selected as support vectors (these are usually instances that are hard to classify)

# make a dataframe of the training data
#df_tested_on = X_sub.iloc[train_indices] # saved from above, the indices chosen for training
df_tested_on = schoolData_pick2.iloc[train_indices] # saved from above, the indices chosen for training
# now get the support vectors from the trained model
df_support = df_tested_on.iloc[svm_clf.support_,:]

df_support['SPG Grade'] = ys2[svm_clf.support_] # add back in the 'Survived' Column to the pandas dataframe
#X_sub['SPG Grade'] = y # also add it back in for the original data
schoolData_pick2['SPG Grade'] = ys2 # also add it back in for the original data['SPG Grade'] = y # also add it back in for the original data
df_support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6457 entries, 3504 to 9264
# Data columns (total 51 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   TotalTargets_pTarget_PctMet        6457 non-null   float64
#  1   EVAAS Growth Status_NotMet         6457 non-null   int64
#  2   MinorityMalePct                    6457 non-null   float64
#  3   MinorityFemalePct                  6457 non-null   float64
#  4   title1_type_cd_Y                   6457 non-null   int64
#  5   avg_daily_attend_pct               6457 non-null   float64
#  6   short_susp_per_c_num               6457 non-null   float64
#  7   BlackMalePct                       6457 non-null   float64
#  8   AsianFemalePct                     6457 non-null   float64
#  9   student_num                        6457 non-null   int64
#  10  HispanicMalePct                    6457 non-null   float64
#  11  SciGr5&8_pTarget_PctMet            6457 non-null   float64
#  12  tchyrs_0thru3_pct                  6457 non-null   float64
#  13  tchyrs_11plus_pct                  6457 non-null   float64
#  14  Accomplished_TCHR_Standard 2_Pct   6457 non-null   float64
#  15  Accomplished_TCHR_Standard 1_Pct   6457 non-null   float64
#  16  Developing_TCHR_Standard 1_Pct     6457 non-null   float64
#  17  Developing_TCHR_Standard 2_Pct     6457 non-null   float64
#  18  Developing_TCHR_Standard 3_Pct     6457 non-null   float64
#  19  Accomplished_TCHR_Standard 4_Pct   6457 non-null   float64
#  20  4-10 Years_LEA_Exp_Pct_Prin        6457 non-null   float64
#  21  Developing_TCHR_Standard 4_Pct     6457 non-null   float64
#  22  Developing_TCHR_Standard 5_Pct     6457 non-null   float64
#  23  10+ Years_LEA_Exp_Pct_Prin         6457 non-null   float64
#  24  Accomplished_TCHR_Standard 3_Pct   6457 non-null   float64
#  25  Accomplished_TCHR_Standard 5_Pct   6457 non-null   float64
#  26  lea_state_perpupil_num             6457 non-null   float64
#  27  st_emer_prov_teach_pct             6457 non-null   float64
#  28  pct_GCE_ALL                        6457 non-null   float64
#  29  MathGr3-8_pTarget_PctMet           6457 non-null   float64
#  30  lea_sat_avg_score_num              6457 non-null   int64
#  31  lea_federal_perpupil_num           6457 non-null   float64
#  32  lea_local_perpupil_num             6457 non-null   float64
#  33  nbpts_num                          6457 non-null   int64
#  34  Distinguished_TCHR_Standard 2_Pct  6457 non-null   float64
#  35  _1yr_tchr_trnovr_pct               6457 non-null   float64
#  36  lateral_teach_pct                  6457 non-null   float64
#  37  0-3 Years_LEA_Exp_Pct_Prin         6457 non-null   float64
#  38  lea_flicensed_teach_pct            6457 non-null   float64
#  39  lea_tchyrs_4thru10_pct             6457 non-null   float64
#  40  lea_tchyrs_11plus_pct              6457 non-null   float64
#  41  lea_nbpts_num                      6457 non-null   int64
#  42  lea_advance_dgr_pct                6457 non-null   float64
#  43  lea_1yr_tchr_trnovr_pct            6457 non-null   float64
#  44  lea_emer_prov_teach_pct            6457 non-null   float64
#  45  st_flicensed_teach_pct             6457 non-null   float64
#  46  st_tchyrs_0thru3_pct               6457 non-null   float64
#  47  st_1yr_tchr_trnovr_pct             6457 non-null   float64
#  48  lea_tchyrs_0thru3_pct              6457 non-null   float64
#  49  Category_Cd_T                      6457 non-null   int64
#  50  SPG Grade                          6457 non-null   object
# dtypes: float64(43), int64(7), object(1)
# memory usage: 2.6+ MB
# C:\Users\taniat470s\Anaconda3\envs\ML7331\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\taniat470s\Anaconda3\envs\ML7331\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# now lets see the statistics of these attributes
#from pandas.tools.plotting import boxplot
from pandas.plotting import boxplot
from matplotlib import pyplot as plt

# group the original data and the support vectors
df_grouped_support = df_support.groupby(['SPG Grade'])
#df_grouped = X_sub.groupby(['SPG Grade'])
df_grouped = schoolData_pick2.groupby(['SPG Grade'])

# plot KDE of Different variables
vars_to_plot = ['tchyrs_0thru3_pct','avg_daily_attend_pct','short_susp_per_c_num','MinorityFemalePct']

for v in vars_to_plot:
    plt.figure(figsize=(10,4))
    # plot support vector stats
    plt.subplot(1,2,1)
    ax = df_grouped_support[v].plot.kde() 
    plt.legend(['A','B','C','D','F'])
    plt.title(v+' (Instances chosen as Support Vectors)')
    
    # plot original distributions
    plt.subplot(1,2,2)
    ax = df_grouped[v].plot.kde() 
    plt.legend(['A','B','C','D','F'])
    plt.title(v+' (Original)')
# Out:
# Text(0.5, 1.0, 'tchyrs_0thru3_pct (Instances chosen as Support Vectors)')
# Text(0.5, 1.0, 'tchyrs_0thru3_pct (Original)')
# Text(0.5, 1.0, 'avg_daily_attend_pct (Instances chosen as Support Vectors)')
# Text(0.5, 1.0, 'avg_daily_attend_pct (Original)')
# Text(0.5, 1.0, 'short_susp_per_c_num (Instances chosen as Support Vectors)')
# Text(0.5, 1.0, 'short_susp_per_c_num (Original)')
# Text(0.5, 1.0, 'MinorityFemalePct (Instances chosen as Support Vectors)')
# Text(0.5, 1.0, 'MinorityFemalePct (Original)')
