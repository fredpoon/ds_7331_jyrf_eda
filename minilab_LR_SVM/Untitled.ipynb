# %%
import pandas as pd
schoolData = pd.read_csv('C:/Users/taniat470s/Desktop/SMU_course/DS7331/PublicSchools2014to2017_YZ.csv') # read in the csv file

# %%
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
uniqueThreshold = 25

#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9731 entries, 0 to 9730
# Columns: 250 entries, szip_ad to Year
# dtypes: float64(237), int64(2), object(11)
# memory usage: 18.6+ MB
#
# Columns Deleted:  9

# %%
schoolData.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9731 entries, 0 to 9730
# Data columns (total 250 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   szip_ad                              float64
#  1   category_cd                          object
#  2   calendar_type_txt                    object
#  3   sna_pgm_type_cd                      object
#  4   school_type_txt                      object
#  5   calendar_only_txt                    object
#  6   title1_type_cd                       object
#  7   esea_status                          object
#  8   student_num                          float64
#  9   lea_avg_student_num                  float64
#  10  st_avg_student_num                   float64
#  11  Grad_project_status                  object
#  12  Math I_Size                          float64
#  13  lea_total_expense_num                float64
#  14  lea_salary_expense_pct               float64
#  15  lea_services_expense_pct             float64
#  16  lea_supplies_expense_pct             float64
#  17  lea_instruct_equip_exp_pct           float64
#  18  lea_federal_perpupil_num             float64
#  19  lea_local_perpupil_num               float64
#  20  lea_state_perpupil_num               float64
#  21  SPG Grade                            object
#  22  SPG Score                            float64
#  23  EVAAS Growth Status                  object
#  24  EVAAS Growth Score                   float64
#  25  Science Score                        float64
#  26  EOG/EOCSubjects_CACR_All             float64
#  27  EOGGr3_CACR_All                      float64
#  28  EOGGr4_CACR_All                      float64
#  29  EOGGr5_CACR_All                      float64
#  30  EOCMathI_CACR_AmericanIndian         float64
#  31  EOCSubjects_CACR_AmericanIndian      float64
#  32  EOG/EOCSubjects_CACR_AmericanIndian  float64
#  33  EOGGr3_CACR_AmericanIndian           float64
#  34  EOGGr4_CACR_AmericanIndian           float64
#  35  EOGGr5_CACR_AmericanIndian           float64
#  36  EOGMathGr3_CACR_AmericanIndian       float64
#  37  EOGMathGr3-8_CACR_AmericanIndian     float64
#  38  EOGMathGr4_CACR_AmericanIndian       float64
#  39  EOGMathGr5_CACR_AmericanIndian       float64
#  40  EOGReadingGr3-8_CACR_AmericanIndian  float64
#  41  EOGScienceGr5_CACR_AmericanIndian    float64
#  42  EOGScienceGr5&8_CACR_AmericanIndian  float64
#  43  EOGSubjects_CACR_AmericanIndian      float64
#  44  EOCMathI_CACR_Asian                  float64
#  45  EOCSubjects_CACR_Asian               float64
#  46  EOG/EOCSubjects_CACR_Asian           float64
#  47  EOGGr3_CACR_Asian                    float64
#  48  EOGGr4_CACR_Asian                    float64
#  49  EOGGr5_CACR_Asian                    float64
#  50  EOGMathGr3_CACR_Asian                float64
#  51  EOGMathGr3-8_CACR_Asian              float64
#  52  EOGMathGr4_CACR_Asian                float64
#  53  EOGMathGr5_CACR_Asian                float64
#  54  EOGScienceGr5&8_CACR_Asian           float64
#  55  EOGSubjects_CACR_Asian               float64
#  56  EOCMathI_CACR_Black                  float64
#  57  EOG/EOCSubjects_CACR_Black           float64
#  58  EOGGr3_CACR_Black                    float64
#  59  EOGGr4_CACR_Black                    float64
#  60  EOGGr5_CACR_Black                    float64
#  61  EOGMathGr3_CACR_Black                float64
#  62  EOGMathGr3-8_CACR_Black              float64
#  63  EOGMathGr4_CACR_Black                float64
#  64  EOGMathGr5_CACR_Black                float64
#  65  EOGReadingGr3_CACR_Black             float64
#  66  EOGReadingGr3-8_CACR_Black           float64
#  67  EOGReadingGr4_CACR_Black             float64
#  68  EOGReadingGr5_CACR_Black             float64
#  69  EOGScienceGr5_CACR_Black             float64
#  70  EOGScienceGr5&8_CACR_Black           float64
#  71  EOGSubjects_CACR_Black               float64
#  72  EOCMathI_CACR_Hispanic               float64
#  73  EOG/EOCSubjects_CACR_Hispanic        float64
#  74  EOGGr3_CACR_Hispanic                 float64
#  75  EOGGr4_CACR_Hispanic                 float64
#  76  EOGGr5_CACR_Hispanic                 float64
#  77  EOGMathGr3_CACR_Hispanic             float64
#  78  EOGMathGr3-8_CACR_Hispanic           float64
#  79  EOGMathGr4_CACR_Hispanic             float64
#  80  EOGMathGr5_CACR_Hispanic             float64
#  81  EOGReadingGr3_CACR_Hispanic          float64
#  82  EOGReadingGr3-8_CACR_Hispanic        float64
#  83  EOGReadingGr4_CACR_Hispanic          float64
#  84  EOGReadingGr5_CACR_Hispanic          float64
#  85  EOGScienceGr5&8_CACR_Hispanic        float64
#  86  EOGSubjects_CACR_Hispanic            float64
#  87  EOCMathI_CACR_TwoorMoreRaces         float64
#  88  EOCSubjects_CACR_TwoorMoreRaces      float64
#  89  EOG/EOCSubjects_CACR_TwoorMoreRaces  float64
#  90  EOGGr3_CACR_TwoorMoreRaces           float64
#  91  EOGGr4_CACR_TwoorMoreRaces           float64
#  92  EOGGr5_CACR_TwoorMoreRaces           float64
#  93  EOGMathGr3_CACR_TwoorMoreRaces       float64
#  94  EOGMathGr3-8_CACR_TwoorMoreRaces     float64
#  95  EOGMathGr4_CACR_TwoorMoreRaces       float64
#  96  EOGMathGr5_CACR_TwoorMoreRaces       float64
#  97  EOGReadingGr3-8_CACR_TwoorMoreRaces  float64
#  98  EOGScienceGr5&8_CACR_TwoorMoreRaces  float64
#  99  EOGSubjects_CACR_TwoorMoreRaces      float64
#  100 EOG/EOCSubjects_CACR_White           float64
#  101 EOGGr4_CACR_White                    float64
#  102 EOGMathGr3-8_CACR_White              float64
#  103 EOGScienceGr5&8_CACR_White           float64
#  104 EOCMathI_CACR_EDS                    float64
#  105 EOG/EOCSubjects_CACR_EDS             float64
#  106 EOGMathGr3-8_CACR_EDS                float64
#  107 EOGReadingGr3-8_CACR_EDS             float64
#  108 EOGReadingGr5_CACR_EDS               float64
#  109 EOGScienceGr5&8_CACR_EDS             float64
#  110 EOCMathI_CACR_LEP                    float64
#  111 EOCMathI_GLP_LEP                     float64
#  112 EOCSubjects_CACR_LEP                 float64
#  113 EOCSubjects_GLP_LEP                  float64
#  114 EOG/EOCSubjects_CACR_LEP             float64
#  115 EOGGr3_CACR_LEP                      float64
#  116 EOGGr4_CACR_LEP                      float64
#  117 EOGGr5_CACR_LEP                      float64
#  118 EOGMathGr3_CACR_LEP                  float64
#  119 EOGMathGr3-8_CACR_LEP                float64
#  120 EOGMathGr4_CACR_LEP                  float64
#  121 EOGMathGr5_CACR_LEP                  float64
#  122 EOGReadingGr3_CACR_LEP               float64
#  123 EOGReadingGr3-8_CACR_LEP             float64
#  124 EOGReadingGr3-8_GLP_LEP              float64
#  125 EOGReadingGr4_CACR_LEP               float64
#  126 EOGReadingGr4_GLP_LEP                float64
#  127 EOGReadingGr5_CACR_LEP               float64
#  128 EOGReadingGr5_GLP_LEP                float64
#  129 EOGScienceGr5_CACR_LEP               float64
#  130 EOGScienceGr5&8_CACR_LEP             float64
#  131 EOCMathI_CACR_SWD                    float64
#  132 EOCMathI_GLP_SWD                     float64
#  133 EOCSubjects_CACR_SWD                 float64
#  134 EOG/EOCSubjects_CACR_SWD             float64
#  135 EOGGr3_CACR_SWD                      float64
#  136 EOGGr4_CACR_SWD                      float64
#  137 EOGGr5_CACR_SWD                      float64
#  138 EOGMathGr3_CACR_SWD                  float64
#  139 EOGMathGr3_GLP_SWD                   float64
#  140 EOGMathGr3-8_CACR_SWD                float64
#  141 EOGMathGr4_CACR_SWD                  float64
#  142 EOGMathGr5_CACR_SWD                  float64
#  143 EOGReadingGr3_CACR_SWD               float64
#  144 EOGReadingGr3-8_CACR_SWD             float64
#  145 EOGReadingGr3-8_GLP_SWD              float64
#  146 EOGReadingGr4_CACR_SWD               float64
#  147 EOGReadingGr4_GLP_SWD                float64
#  148 EOGReadingGr5_CACR_SWD               float64
#  149 EOGReadingGr5_GLP_SWD                float64
#  150 EOGScienceGr5_CACR_SWD               float64
#  151 EOGScienceGr5&8_CACR_SWD             float64
#  152 EOGSubjects_CACR_SWD                 float64
#  153 EOCMathI_CACR_AIG                    float64
#  154 EOG/EOCSubjects_CACR_AIG             float64
#  155 EOGGr3_CACR_AIG                      float64
#  156 EOGGr4_CACR_AIG                      float64
#  157 EOGGr5_CACR_AIG                      float64
#  158 EOGMathGr3_CACR_AIG                  float64
#  159 EOGMathGr3-8_CACR_AIG                float64
#  160 EOGMathGr4_CACR_AIG                  float64
#  161 EOGMathGr5_CACR_AIG                  float64
#  162 EOGScienceGr5&8_CACR_AIG             float64
#  163 EOGSubjects_CACR_AIG                 float64
#  164 pct_GCE_ALL                          float64
#  165 MathGr3-8_pTarget_PctMet             float64
#  166 SciGr5&8_pTarget_PctMet              float64
#  167 TotalTargets_pTarget_PctMet          float64
#  168 Category_Cd                          object
#  169 lea_sat_avg_score_num                float64
#  170 lea_sat_participation_pct            float64
#  171 lea_ap_participation_pct             float64
#  172 lea_ap_pct_3_or_above                float64
#  173 lea_ib_pct_4_or_above                float64
#  174 avg_daily_attend_pct                 float64
#  175 crime_per_c_num                      float64
#  176 short_susp_per_c_num                 float64
#  177 long_susp_per_c_num                  float64
#  178 expelled_per_c_num                   float64
#  179 stud_internet_comp_num               float64
#  180 lea_avg_daily_attend_pct             float64
#  181 lea_crime_per_c_num                  float64
#  182 lea_short_susp_per_c_num             float64
#  183 lea_long_susp_per_c_num              float64
#  184 lea_expelled_per_c_num               float64
#  185 lea_stud_internet_comp_num           float64
#  186 st_crime_per_c_num                   float64
#  187 flicensed_teach_pct                  float64
#  188 tchyrs_0thru3_pct                    float64
#  189 tchyrs_4thru10_pct                   float64
#  190 tchyrs_11plus_pct                    float64
#  191 nbpts_num                            float64
#  192 advance_dgr_pct                      float64
#  193 _1yr_tchr_trnovr_pct                 float64
#  194 lateral_teach_pct                    float64
#  195 lea_flicensed_teach_pct              float64
#  196 lea_tchyrs_0thru3_pct                float64
#  197 lea_tchyrs_4thru10_pct               float64
#  198 lea_tchyrs_11plus_pct                float64
#  199 lea_nbpts_num                        float64
#  200 lea_advance_dgr_pct                  float64
#  201 lea_1yr_tchr_trnovr_pct              float64
#  202 lea_emer_prov_teach_pct              float64
#  203 st_flicensed_teach_pct               float64
#  204 st_tchyrs_0thru3_pct                 float64
#  205 st_1yr_tchr_trnovr_pct               float64
#  206 st_emer_prov_teach_pct               float64
#  207 0-3 Years_LEA_Exp_Pct_Prin           float64
#  208 10+ Years_LEA_Exp_Pct_Prin           float64
#  209 4-10 Years_LEA_Exp_Pct_Prin          float64
#  210 Accomplished_TCHR_Standard 1_Pct     float64
#  211 Accomplished_TCHR_Standard 2_Pct     float64
#  212 Accomplished_TCHR_Standard 3_Pct     float64
#  213 Accomplished_TCHR_Standard 4_Pct     float64
#  214 Accomplished_TCHR_Standard 5_Pct     float64
#  215 Developing_TCHR_Standard 1_Pct       float64
#  216 Developing_TCHR_Standard 2_Pct       float64
#  217 Developing_TCHR_Standard 3_Pct       float64
#  218 Developing_TCHR_Standard 4_Pct       float64
#  219 Developing_TCHR_Standard 5_Pct       float64
#  220 Distinguished_TCHR_Standard 1_Pct    float64
#  221 Distinguished_TCHR_Standard 2_Pct    float64
#  222 Distinguished_TCHR_Standard 3_Pct    float64
#  223 Distinguished_TCHR_Standard 4_Pct    float64
#  224 Distinguished_TCHR_Standard 5_Pct    float64
#  225 Not Demostrated_TCHR_Standard 1_Pct  float64
#  226 Not Demostrated_TCHR_Standard 2_Pct  float64
#  227 Not Demostrated_TCHR_Standard 4_Pct  float64
#  228 Proficient_TCHR_Standard 1_Pct       float64
#  229 Proficient_TCHR_Standard 2_Pct       float64
#  230 Proficient_TCHR_Standard 3_Pct       float64
#  231 Proficient_TCHR_Standard 4_Pct       float64
#  232 Proficient_TCHR_Standard 5_Pct       float64
#  233 AsianFemalePct                       float64
#  234 AsianMalePct                         float64
#  235 BlackFemalePct                       float64
#  236 BlackMalePct                         float64
#  237 HispanicFemalePct                    float64
#  238 HispanicMalePct                      float64
#  239 IndianFemalePct                      float64
#  240 MinorityFemalePct                    float64
#  241 MinorityMalePct                      float64
#  242 PacificIslandFemalePct               float64
#  243 PacificIslandMalePct                 float64
#  244 PacificIslandPct                     float64
#  245 TwoOrMoreFemalePct                   float64
#  246 TwoOrMoreMalePct                     float64
#  247 TwoOrMorePct                         float64
#  248 unit_code                            int64
#  249 Year                                 int64
# dtypes: float64(237), int64(2), object(11)
# memory usage: 18.6+ MB

# %%
schoolData_SPG = schoolData.pop('SPG Grade')
schoolData_SPGScore = schoolData.pop('SPG Score')

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData,drop_first=True)

# %%
#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt


#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print ('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  20
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9731 entries, 0 to 9730
# Columns: 288 entries, szip_ad to Category_Cd_T
# dtypes: float64(236), int64(2), uint8(50)
# memory usage: 18.1 MB
#
# New Columns Created Via One-Hot Encoding:  40

# %%
schoolData.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9731 entries, 0 to 9730
# Data columns (total 288 columns):
#  #   Column                                                                           Dtype
# ---  ------                                                                           -----
#  0   szip_ad                                                                          float64
#  1   student_num                                                                      float64
#  2   lea_avg_student_num                                                              float64
#  3   st_avg_student_num                                                               float64
#  4   Math I_Size                                                                      float64
#  5   lea_total_expense_num                                                            float64
#  6   lea_salary_expense_pct                                                           float64
#  7   lea_services_expense_pct                                                         float64
#  8   lea_supplies_expense_pct                                                         float64
#  9   lea_instruct_equip_exp_pct                                                       float64
#  10  lea_federal_perpupil_num                                                         float64
#  11  lea_local_perpupil_num                                                           float64
#  12  lea_state_perpupil_num                                                           float64
#  13  EVAAS Growth Score                                                               float64
#  14  Science Score                                                                    float64
#  15  EOG/EOCSubjects_CACR_All                                                         float64
#  16  EOGGr3_CACR_All                                                                  float64
#  17  EOGGr4_CACR_All                                                                  float64
#  18  EOGGr5_CACR_All                                                                  float64
#  19  EOCMathI_CACR_AmericanIndian                                                     float64
#  20  EOCSubjects_CACR_AmericanIndian                                                  float64
#  21  EOG/EOCSubjects_CACR_AmericanIndian                                              float64
#  22  EOGGr3_CACR_AmericanIndian                                                       float64
#  23  EOGGr4_CACR_AmericanIndian                                                       float64
#  24  EOGGr5_CACR_AmericanIndian                                                       float64
#  25  EOGMathGr3_CACR_AmericanIndian                                                   float64
#  26  EOGMathGr3-8_CACR_AmericanIndian                                                 float64
#  27  EOGMathGr4_CACR_AmericanIndian                                                   float64
#  28  EOGMathGr5_CACR_AmericanIndian                                                   float64
#  29  EOGReadingGr3-8_CACR_AmericanIndian                                              float64
#  30  EOGScienceGr5_CACR_AmericanIndian                                                float64
#  31  EOGScienceGr5&8_CACR_AmericanIndian                                              float64
#  32  EOGSubjects_CACR_AmericanIndian                                                  float64
#  33  EOCMathI_CACR_Asian                                                              float64
#  34  EOCSubjects_CACR_Asian                                                           float64
#  35  EOG/EOCSubjects_CACR_Asian                                                       float64
#  36  EOGGr3_CACR_Asian                                                                float64
#  37  EOGGr4_CACR_Asian                                                                float64
#  38  EOGGr5_CACR_Asian                                                                float64
#  39  EOGMathGr3_CACR_Asian                                                            float64
#  40  EOGMathGr3-8_CACR_Asian                                                          float64
#  41  EOGMathGr4_CACR_Asian                                                            float64
#  42  EOGMathGr5_CACR_Asian                                                            float64
#  43  EOGScienceGr5&8_CACR_Asian                                                       float64
#  44  EOGSubjects_CACR_Asian                                                           float64
#  45  EOCMathI_CACR_Black                                                              float64
#  46  EOG/EOCSubjects_CACR_Black                                                       float64
#  47  EOGGr3_CACR_Black                                                                float64
#  48  EOGGr4_CACR_Black                                                                float64
#  49  EOGGr5_CACR_Black                                                                float64
#  50  EOGMathGr3_CACR_Black                                                            float64
#  51  EOGMathGr3-8_CACR_Black                                                          float64
#  52  EOGMathGr4_CACR_Black                                                            float64
#  53  EOGMathGr5_CACR_Black                                                            float64
#  54  EOGReadingGr3_CACR_Black                                                         float64
#  55  EOGReadingGr3-8_CACR_Black                                                       float64
#  56  EOGReadingGr4_CACR_Black                                                         float64
#  57  EOGReadingGr5_CACR_Black                                                         float64
#  58  EOGScienceGr5_CACR_Black                                                         float64
#  59  EOGScienceGr5&8_CACR_Black                                                       float64
#  60  EOGSubjects_CACR_Black                                                           float64
#  61  EOCMathI_CACR_Hispanic                                                           float64
#  62  EOG/EOCSubjects_CACR_Hispanic                                                    float64
#  63  EOGGr3_CACR_Hispanic                                                             float64
#  64  EOGGr4_CACR_Hispanic                                                             float64
#  65  EOGGr5_CACR_Hispanic                                                             float64
#  66  EOGMathGr3_CACR_Hispanic                                                         float64
#  67  EOGMathGr3-8_CACR_Hispanic                                                       float64
#  68  EOGMathGr4_CACR_Hispanic                                                         float64
#  69  EOGMathGr5_CACR_Hispanic                                                         float64
#  70  EOGReadingGr3_CACR_Hispanic                                                      float64
#  71  EOGReadingGr3-8_CACR_Hispanic                                                    float64
#  72  EOGReadingGr4_CACR_Hispanic                                                      float64
#  73  EOGReadingGr5_CACR_Hispanic                                                      float64
#  74  EOGScienceGr5&8_CACR_Hispanic                                                    float64
#  75  EOGSubjects_CACR_Hispanic                                                        float64
#  76  EOCMathI_CACR_TwoorMoreRaces                                                     float64
#  77  EOCSubjects_CACR_TwoorMoreRaces                                                  float64
#  78  EOG/EOCSubjects_CACR_TwoorMoreRaces                                              float64
#  79  EOGGr3_CACR_TwoorMoreRaces                                                       float64
#  80  EOGGr4_CACR_TwoorMoreRaces                                                       float64
#  81  EOGGr5_CACR_TwoorMoreRaces                                                       float64
#  82  EOGMathGr3_CACR_TwoorMoreRaces                                                   float64
#  83  EOGMathGr3-8_CACR_TwoorMoreRaces                                                 float64
#  84  EOGMathGr4_CACR_TwoorMoreRaces                                                   float64
#  85  EOGMathGr5_CACR_TwoorMoreRaces                                                   float64
#  86  EOGReadingGr3-8_CACR_TwoorMoreRaces                                              float64
#  87  EOGScienceGr5&8_CACR_TwoorMoreRaces                                              float64
#  88  EOGSubjects_CACR_TwoorMoreRaces                                                  float64
#  89  EOG/EOCSubjects_CACR_White                                                       float64
#  90  EOGGr4_CACR_White                                                                float64
#  91  EOGMathGr3-8_CACR_White                                                          float64
#  92  EOGScienceGr5&8_CACR_White                                                       float64
#  93  EOCMathI_CACR_EDS                                                                float64
#  94  EOG/EOCSubjects_CACR_EDS                                                         float64
#  95  EOGMathGr3-8_CACR_EDS                                                            float64
#  96  EOGReadingGr3-8_CACR_EDS                                                         float64
#  97  EOGReadingGr5_CACR_EDS                                                           float64
#  98  EOGScienceGr5&8_CACR_EDS                                                         float64
#  99  EOCMathI_CACR_LEP                                                                float64
#  100 EOCMathI_GLP_LEP                                                                 float64
#  101 EOCSubjects_CACR_LEP                                                             float64
#  102 EOCSubjects_GLP_LEP                                                              float64
#  103 EOG/EOCSubjects_CACR_LEP                                                         float64
#  104 EOGGr3_CACR_LEP                                                                  float64
#  105 EOGGr4_CACR_LEP                                                                  float64
#  106 EOGGr5_CACR_LEP                                                                  float64
#  107 EOGMathGr3_CACR_LEP                                                              float64
#  108 EOGMathGr3-8_CACR_LEP                                                            float64
#  109 EOGMathGr4_CACR_LEP                                                              float64
#  110 EOGMathGr5_CACR_LEP                                                              float64
#  111 EOGReadingGr3_CACR_LEP                                                           float64
#  112 EOGReadingGr3-8_CACR_LEP                                                         float64
#  113 EOGReadingGr3-8_GLP_LEP                                                          float64
#  114 EOGReadingGr4_CACR_LEP                                                           float64
#  115 EOGReadingGr4_GLP_LEP                                                            float64
#  116 EOGReadingGr5_CACR_LEP                                                           float64
#  117 EOGReadingGr5_GLP_LEP                                                            float64
#  118 EOGScienceGr5_CACR_LEP                                                           float64
#  119 EOGScienceGr5&8_CACR_LEP                                                         float64
#  120 EOCMathI_CACR_SWD                                                                float64
#  121 EOCMathI_GLP_SWD                                                                 float64
#  122 EOCSubjects_CACR_SWD                                                             float64
#  123 EOG/EOCSubjects_CACR_SWD                                                         float64
#  124 EOGGr3_CACR_SWD                                                                  float64
#  125 EOGGr4_CACR_SWD                                                                  float64
#  126 EOGGr5_CACR_SWD                                                                  float64
#  127 EOGMathGr3_CACR_SWD                                                              float64
#  128 EOGMathGr3_GLP_SWD                                                               float64
#  129 EOGMathGr3-8_CACR_SWD                                                            float64
#  130 EOGMathGr4_CACR_SWD                                                              float64
#  131 EOGMathGr5_CACR_SWD                                                              float64
#  132 EOGReadingGr3_CACR_SWD                                                           float64
#  133 EOGReadingGr3-8_CACR_SWD                                                         float64
#  134 EOGReadingGr3-8_GLP_SWD                                                          float64
#  135 EOGReadingGr4_CACR_SWD                                                           float64
#  136 EOGReadingGr4_GLP_SWD                                                            float64
#  137 EOGReadingGr5_CACR_SWD                                                           float64
#  138 EOGReadingGr5_GLP_SWD                                                            float64
#  139 EOGScienceGr5_CACR_SWD                                                           float64
#  140 EOGScienceGr5&8_CACR_SWD                                                         float64
#  141 EOGSubjects_CACR_SWD                                                             float64
#  142 EOCMathI_CACR_AIG                                                                float64
#  143 EOG/EOCSubjects_CACR_AIG                                                         float64
#  144 EOGGr3_CACR_AIG                                                                  float64
#  145 EOGGr4_CACR_AIG                                                                  float64
#  146 EOGGr5_CACR_AIG                                                                  float64
#  147 EOGMathGr3_CACR_AIG                                                              float64
#  148 EOGMathGr3-8_CACR_AIG                                                            float64
#  149 EOGMathGr4_CACR_AIG                                                              float64
#  150 EOGMathGr5_CACR_AIG                                                              float64
#  151 EOGScienceGr5&8_CACR_AIG                                                         float64
#  152 EOGSubjects_CACR_AIG                                                             float64
#  153 pct_GCE_ALL                                                                      float64
#  154 MathGr3-8_pTarget_PctMet                                                         float64
#  155 SciGr5&8_pTarget_PctMet                                                          float64
#  156 TotalTargets_pTarget_PctMet                                                      float64
#  157 lea_sat_avg_score_num                                                            float64
#  158 lea_sat_participation_pct                                                        float64
#  159 lea_ap_participation_pct                                                         float64
#  160 lea_ap_pct_3_or_above                                                            float64
#  161 lea_ib_pct_4_or_above                                                            float64
#  162 avg_daily_attend_pct                                                             float64
#  163 crime_per_c_num                                                                  float64
#  164 short_susp_per_c_num                                                             float64
#  165 long_susp_per_c_num                                                              float64
#  166 expelled_per_c_num                                                               float64
#  167 stud_internet_comp_num                                                           float64
#  168 lea_avg_daily_attend_pct                                                         float64
#  169 lea_crime_per_c_num                                                              float64
#  170 lea_short_susp_per_c_num                                                         float64
#  171 lea_long_susp_per_c_num                                                          float64
#  172 lea_expelled_per_c_num                                                           float64
#  173 lea_stud_internet_comp_num                                                       float64
#  174 st_crime_per_c_num                                                               float64
#  175 flicensed_teach_pct                                                              float64
#  176 tchyrs_0thru3_pct                                                                float64
#  177 tchyrs_4thru10_pct                                                               float64
#  178 tchyrs_11plus_pct                                                                float64
#  179 nbpts_num                                                                        float64
#  180 advance_dgr_pct                                                                  float64
#  181 _1yr_tchr_trnovr_pct                                                             float64
#  182 lateral_teach_pct                                                                float64
#  183 lea_flicensed_teach_pct                                                          float64
#  184 lea_tchyrs_0thru3_pct                                                            float64
#  185 lea_tchyrs_4thru10_pct                                                           float64
#  186 lea_tchyrs_11plus_pct                                                            float64
#  187 lea_nbpts_num                                                                    float64
#  188 lea_advance_dgr_pct                                                              float64
#  189 lea_1yr_tchr_trnovr_pct                                                          float64
#  190 lea_emer_prov_teach_pct                                                          float64
#  191 st_flicensed_teach_pct                                                           float64
#  192 st_tchyrs_0thru3_pct                                                             float64
#  193 st_1yr_tchr_trnovr_pct                                                           float64
#  194 st_emer_prov_teach_pct                                                           float64
#  195 0-3 Years_LEA_Exp_Pct_Prin                                                       float64
#  196 10+ Years_LEA_Exp_Pct_Prin                                                       float64
#  197 4-10 Years_LEA_Exp_Pct_Prin                                                      float64
#  198 Accomplished_TCHR_Standard 1_Pct                                                 float64
#  199 Accomplished_TCHR_Standard 2_Pct                                                 float64
#  200 Accomplished_TCHR_Standard 3_Pct                                                 float64
#  201 Accomplished_TCHR_Standard 4_Pct                                                 float64
#  202 Accomplished_TCHR_Standard 5_Pct                                                 float64
#  203 Developing_TCHR_Standard 1_Pct                                                   float64
#  204 Developing_TCHR_Standard 2_Pct                                                   float64
#  205 Developing_TCHR_Standard 3_Pct                                                   float64
#  206 Developing_TCHR_Standard 4_Pct                                                   float64
#  207 Developing_TCHR_Standard 5_Pct                                                   float64
#  208 Distinguished_TCHR_Standard 1_Pct                                                float64
#  209 Distinguished_TCHR_Standard 2_Pct                                                float64
#  210 Distinguished_TCHR_Standard 3_Pct                                                float64
#  211 Distinguished_TCHR_Standard 4_Pct                                                float64
#  212 Distinguished_TCHR_Standard 5_Pct                                                float64
#  213 Not Demostrated_TCHR_Standard 1_Pct                                              float64
#  214 Not Demostrated_TCHR_Standard 2_Pct                                              float64
#  215 Not Demostrated_TCHR_Standard 4_Pct                                              float64
#  216 Proficient_TCHR_Standard 1_Pct                                                   float64
#  217 Proficient_TCHR_Standard 2_Pct                                                   float64
#  218 Proficient_TCHR_Standard 3_Pct                                                   float64
#  219 Proficient_TCHR_Standard 4_Pct                                                   float64
#  220 Proficient_TCHR_Standard 5_Pct                                                   float64
#  221 AsianFemalePct                                                                   float64
#  222 AsianMalePct                                                                     float64
#  223 BlackFemalePct                                                                   float64
#  224 BlackMalePct                                                                     float64
#  225 HispanicFemalePct                                                                float64
#  226 HispanicMalePct                                                                  float64
#  227 IndianFemalePct                                                                  float64
#  228 MinorityFemalePct                                                                float64
#  229 MinorityMalePct                                                                  float64
#  230 PacificIslandFemalePct                                                           float64
#  231 PacificIslandMalePct                                                             float64
#  232 PacificIslandPct                                                                 float64
#  233 TwoOrMoreFemalePct                                                               float64
#  234 TwoOrMoreMalePct                                                                 float64
#  235 TwoOrMorePct                                                                     float64
#  236 unit_code                                                                        int64
#  237 Year                                                                             int64
#  238 category_cd_A                                                                    uint8
#  239 category_cd_E                                                                    uint8
#  240 category_cd_H                                                                    uint8
#  241 category_cd_I                                                                    uint8
#  242 category_cd_M                                                                    uint8
#  243 category_cd_T                                                                    uint8
#  244 calendar_type_txt_Alternative Education, Traditional Calendar                    uint8
#  245 calendar_type_txt_Hospital School                                                uint8
#  246 calendar_type_txt_Magnet School, Traditional Calendar                            uint8
#  247 calendar_type_txt_Magnet School, Year-Round Calendar                             uint8
#  248 calendar_type_txt_Regular School, Traditional Calendar                           uint8
#  249 calendar_type_txt_Regular School, Traditional Calendar plus Year-Round Calendar  uint8
#  250 calendar_type_txt_Regular School, Year-Round Calendar                            uint8
#  251 calendar_type_txt_Special Education, Traditional Calendar                        uint8
#  252 calendar_type_txt_Vocational Education, Traditional Calendar                     uint8
#  253 sna_pgm_type_cd_A                                                                uint8
#  254 sna_pgm_type_cd_H                                                                uint8
#  255 sna_pgm_type_cd_M                                                                uint8
#  256 sna_pgm_type_cd_N                                                                uint8
#  257 sna_pgm_type_cd_R                                                                uint8
#  258 sna_pgm_type_cd_S                                                                uint8
#  259 sna_pgm_type_cd_V                                                                uint8
#  260 sna_pgm_type_cd_X                                                                uint8
#  261 sna_pgm_type_cd_Y                                                                uint8
#  262 school_type_txt_Alternative Education                                            uint8
#  263 school_type_txt_Hospital School                                                  uint8
#  264 school_type_txt_Magnet School                                                    uint8
#  265 school_type_txt_Regular School                                                   uint8
#  266 school_type_txt_Special Education                                                uint8
#  267 school_type_txt_Vocational Education                                             uint8
#  268 calendar_only_txt_Traditional Calendar                                           uint8
#  269 calendar_only_txt_Traditional Calendar plus Year-Round Calendar                  uint8
#  270 calendar_only_txt_Year-Round Calendar                                            uint8
#  271 title1_type_cd_Y                                                                 uint8
#  272 esea_status_F                                                                    uint8
#  273 esea_status_P                                                                    uint8
#  274 esea_status_R                                                                    uint8
#  275 esea_status_RF                                                                   uint8
#  276 esea_status_RP                                                                   uint8
#  277 Grad_project_status_N                                                            uint8
#  278 Grad_project_status_Y                                                            uint8
#  279 EVAAS Growth Status_Exceeded                                                     uint8
#  280 EVAAS Growth Status_Met                                                          uint8
#  281 EVAAS Growth Status_NotMet                                                       uint8
#  282 Category_Cd_A                                                                    uint8
#  283 Category_Cd_E                                                                    uint8
#  284 Category_Cd_H                                                                    uint8
#  285 Category_Cd_I                                                                    uint8
#  286 Category_Cd_M                                                                    uint8
#  287 Category_Cd_T                                                                    uint8
# dtypes: float64(236), int64(2), uint8(50)
# memory usage: 18.1 MB

# %%
#Location where the new school datasets will be created.
outputDir = 'C:/Users/taniat470s/Desktop/SMU_course/DS7331/'
schoolData.to_csv(outputDir + 'PublicSchools2014to2017_4ML.csv', sep=',', index=False)
schoolData_SPG.to_csv(outputDir + 'PublicSchools2014to2017_SPG.csv', sep=',', index=False)
